# %%
import requests
from bs4 import BeautifulSoup
import re
import nltk
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Ensure necessary NLTK data is available
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
url = "https://en.wikipedia.org/wiki/United_States_dollar"

# %%
# Send a request to get the page content
response = requests.get(url)

# %%
# Check if request was successful (Status Code 200)
if response.status_code == 200:
    # Step 2: Parse the HTML Content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract main text from the page (excluding scripts and styles)
    for script in soup(["script", "style"]):
        script.extract()  # Remove script and style elements

# %%
# Check if request was successful (Status Code 200)
if response.status_code == 200:
    # Step 2: Parse the HTML Content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract main text from the page (excluding scripts and styles)
    for script in soup(["script", "style"]):
        script.extract()  # Remove script and style elements

    # Get the visible text
    text = soup.get_text(separator=' ')  # Separate lines with spaces

    # Step 3: Clean Text - Remove extra spaces and newlines
    text = re.sub(r'\s+', ' ', text).strip()

    # Print a preview of the text
    print(text[:1000])  # Display the first 1000 characters

else:
    print("Failed to retrieve the webpage. Status Code:", response.status_code)
# Out:
# United States dollar - Wikipedia Jump to content Main menu Main menu move to sidebar hide Navigation Main page Contents Current events Random article About Wikipedia Contact us Special pages Contribute Help Learn to edit Community portal Recent changes Upload file Search Search Appearance Donate Create account Log in Personal tools Donate Create account Log in Pages for logged out editors learn more Contributions Talk Contents move to sidebar hide (Top) 1 Overview Toggle Overview subsection 1.1 In the Constitution 1.2 Coinage Act 1.3 Decimal units 1.4 Etymology 1.5 Nicknames 1.6 Dollar sign 2 History Toggle History subsection 2.1 Origins: the Spanish dollar 2.2 Coinage Act of 1792 2.3 Design 2.4 Continental currency 2.5 Silver and gold standards, 19th century 2.6 Note issues, 19th century 2.7 Gold standard, 20th century 2.8 Federal Reserve Notes, 20th century to present 2.9 Emergence as reserve currency 3 Coins Toggle Coins subsection 3.1 Collector coins 4 Banknotes 5 Countries that 
# ...

# %%
# Step 2: Extract Text
soup = BeautifulSoup(html_content, 'html.parser')
for script_or_style in soup(['script', 'style']):
    script_or_style.decompose()
text = soup.get_text()

# %%
# Step 3: Preprocess Text
text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with a single space
text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove non-alphabetic characters

# %%
# Step 4: Word Tokenize
words = nltk.word_tokenize(text)

# %%
# Step 5: Convert to Lowercase
words = [word.lower() for word in words]

# %%
# Step 6: Remove Stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if word not in stop_words]

# %%
# Step 7: Filter Short Words
words = [word for word in words if len(word) > 2]

# %%
# Step 8: Identify Frequent Words
word_counts = Counter(words)
most_common_words = word_counts.most_common(50)

# %%
# Remove specific unwanted words
unwanted_words = {'also', 'retrievedoctober'}
filtered_words = {word: count for word, count in most_common_words if word not in unwanted_words}

# %%
# Step 9: Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='black').generate_from_frequencies(filtered_words)

# %%
# Display the Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Most Frequent Words')
plt.show()

# %%
#  Extract Text
soup = BeautifulSoup(html_content, 'html.parser')
paragraphs = soup.find_all('p')
text = ' '.join([para.get_text() for para in paragraphs])

# %%
# Remove references in square brackets and non-alphabetic characters
text = re.sub(r'\[.*?\]', '', text)
text = re.sub(r'[^a-zA-Z\s]', '', text)

# %%
# Tokenize Words
words = nltk.word_tokenize(text)

# %%
# Convert to Lowercase
words = [word.lower() for word in words]

# %%
#Remove Stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if word not in stop_words]

# %%
#Filter Short Words
words = [word for word in words if len(word) > 2]

# %%
# Remove specific unwanted words
unwanted_words = {'also', 'retrievedoctober'}
words = [word for word in words if word not in unwanted_words]

# %%
# Count word frequencies
word_freq = Counter(words)
common_words = word_freq.most_common(50)

# %%
# Create a word cloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(common_words))

# %%
# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Top 50 Most Frequent Words in United States Dollar Wikipedia Page')
plt.show()

# %%
text = """
The United States dollar is the official currency of the United States and several other countries.
It is widely used in international trade and finance.
"""

# %%
# Word Tokenization
tokens = word_tokenize(text)

# %%
# Convert to Lowercase
tokens = [word.lower() for word in tokens]

# %%
# Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
# Select Words with More than 2 Characters
final_tokens = [word for word in filtered_tokens if len(word) > 2]

# %%
# Display Output
print("Original Tokens:", tokens[:20])  # First 20 tokens for preview
print("Filtered Tokens:", final_tokens[:20])  # First 20 after processing
# Out:
# Original Tokens: ['the', 'united', 'states', 'dollar', 'is', 'the', 'official', 'currency', 'of', 'the', 'united', 'states', 'and', 'several', 'other', 'countries', '.', 'it', 'is', 'widely']
# Filtered Tokens: ['united', 'states', 'dollar', 'official', 'currency', 'united', 'states', 'several', 'countries', 'widely', 'used', 'international', 'trade', 'finance']

# %%
#g)	Select words with greater than 2 characters
#h)	Find Frequent words, most common 50
#i)	Wordcloud of frequent words

# %%
text = "United States dollar - Wikipedia Jump to content Main menu Main menu move to sidebar hide Navigation Main page Contents Current events Random article About Wikipedia Contact us Special pages Contribute Help Learn to edit Community portal Recent changes Upload file Search Search Appearance Donate Create account Log in Personal tools Donate Create account Log in Pages for logged out editors learn more Contributions Talk Contents move to sidebar hide (Top) 1 Overview Toggle Overview subsection 1.1 In the Constitution 1.2 Coinage Act 1.3 Decimal units 1.4 Etymology 1.5 Nicknames 1.6 Dollar sign 2 History Toggle History subsection 2.1 Origins: the Spanish dollar 2.2 Coinage Act of 1792 2.3 Design 2.4 Continental currency 2.5 Silver and gold standards, 19th century 2.6 Note issues, 19th century 2.7 Gold standard, 20th century 2.8 Federal Reserve Notes, 20th century to present 2.9 Emergence as reserve currency 3 Coins Toggle Coins subsection 3.1 Collector coins 4 Banknotes 5 Countries that us "

# %%
tokens = word_tokenize(text)

# %%
#Convert to Lowercase
tokens = [word.lower() for word in tokens]

# %%
#Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
#Select Words with More than 2 Characters
filtered_tokens = [word for word in filtered_tokens if len(word) > 2]

# %%
#Find the 50 Most Frequent Words
word_counts = Counter(filtered_tokens)  # Count word frequencies
most_common_words = word_counts.most_common(50)  # Get top 50 words

# %%
#Display Most Frequent Words
print("Most Common 50 Words:", most_common_words)
# Out:
# Most Common 50 Words: [('dollar', 355), ('states', 146), ('united', 139), ('u.s.', 132), ('currency', 119), ('reserve', 93), ('gold', 87), ('silver', 82), ('federal', 82), ('archived', 79), ('retrieved', 77), ('coins', 67), ('value', 67), ('original', 63), ('act', 55), ('2018', 50), ('dollars', 48), ('october', 46), ('edit', 44), ('money', 44), ('bank', 43), ('american', 43), ('currencies', 42), ('coinage', 40), ('2021', 40), ('coin', 39), ('note', 38), ('notes', 38), ('war', 38), ('spanish', 37), ('grains', 37), ('pound', 36), ('monetary', 35), ('eagle', 35), ('policy', 34), ('international', 33), ('also', 33), ('new', 32), ('treasury', 32), ('congress', 31), ('standard', 29), ('exchange', 27), ('world', 27), ('peso', 27), ('june', 27), ('used', 26), ('lower', 26), ('denominations', 25), ('system', 25), ('half', 25)]

# %%
#Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white',
                      stopwords=set(["also", "retrievedoctober"]),  # Remove unwanted words
                      colormap='viridis').generate_from_frequencies(dict(most_common_words))

# %%
# Display the Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide axes
plt.title("Word Cloud of Most Frequent Words")
plt.show()

# %%
# : Clean Text - Remove Special Characters
text = re.sub(r'[^a-zA-Z\s]', '', text)

# %%
#: Tokenization
tokens = word_tokenize(text)

# %%
# : Convert to Lowercase
tokens = [word.lower() for word in tokens]

# %%
# : Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
#Step 5: Select Words with More than 2 Characters
filtered_tokens = [word for word in filtered_tokens if len(word) > 2]

# %%
#: Find the 50 Most Frequent Words
word_counts = Counter(filtered_tokens)  # Count word frequencies
most_common_words = word_counts.most_common(50)  # Get top 50 words

# %%
#: Remove Specific Unwanted Words
unwanted_words = {"also", "retrievedoctober"}
filtered_common_words = [(word, count) for word, count in most_common_words if word not in unwanted_words]

# %%
 #Display Most Frequent Words
print("Most Common 50 Words After Filtering:", filtered_common_words)
# Out:
# Most Common 50 Words After Filtering: [('dollar', 346), ('states', 145), ('united', 139), ('currency', 119), ('reserve', 92), ('gold', 87), ('silver', 82), ('federal', 82), ('archived', 79), ('retrieved', 77), ('coins', 67), ('value', 67), ('original', 63), ('act', 55), ('dollars', 55), ('october', 46), ('edit', 44), ('money', 44), ('american', 43), ('currencies', 42), ('coinage', 40), ('bank', 39), ('coin', 39), ('note', 38), ('notes', 38), ('war', 38), ('spanish', 37), ('grains', 37), ('pound', 36), ('monetary', 35), ('eagle', 35), ('policy', 34), ('international', 33), ('new', 32), ('treasury', 32), ('congress', 31), ('standard', 29), ('exchange', 27), ('june', 27), ('used', 26), ('peso', 26), ('lower', 26), ('present', 25), ('denominations', 25), ('system', 25), ('half', 25), ('history', 24), ('rates', 24), ('bill', 24)]

# %%
# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='Orange',
                      colormap='viridis').generate_from_frequencies(dict(filtered_common_words))

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide axes
plt.title("Word Cloud of Most Frequent Words (Cleaned)")
plt.show()
